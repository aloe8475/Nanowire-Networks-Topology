# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('dow_jones_index.csv')

# %%
data
# Out:
#      quarter stock       date    open    high     low   close     volume  \
# 0          1    AA  1/07/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1          1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2          1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3          1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4          1    AA  2/04/2011  $16.18  $17.39  $16.18  $17.14  154387761
# 5          1    AA  2/11/2011  $17.33  $17.48  $16.97  $17.37  114691279
# 6          1    AA  2/18/2011  $17.39  $17.68  $17.28  $17.28   80023895
# 7          1    AA  2/25/2011  $16.98  $17.15  $15.96  $16.68  132981863
# 8          1    AA  3/04/2011  $16.81  $16.94  $16.13  $16.58  109493077
# 9          1    AA  3/11/2011  $16.58  $16.75  $15.42  $16.03  114332562
# 10         1    AA  3/18/2011  $15.95  $16.33  $15.43  $16.11  130374108
# 11         1    AA  3/25/2011  $16.38  $17.24  $16.26  $17.09   95550392
# ...

# %%
date=data['date']
price=data['percent_change_price']

# %%
#price=price.str.lstrip('$').astype(float)

# %%
price.plot()

# %%
a=price
b=price
#split a and b
a1=a

b1=b[0:len(b)//2]
b2=b[len(b)//2:]

# %%
plt.plot(a1)

# %%
a1.to_csv('Dow_Jones_Percentage_Change1.csv',index=False)
# Out:
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
