# %%
cd "C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN"
# Out:
# C:\Users\aloe8475\Dropbox (Sydney Uni)\Data\ASN_simulation\Python\ASN

# %%
from scipy.io import loadmat, savemat
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import networkx as nx
from utils import *

from itertools import permutations 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, Normalizer

import warnings
warnings.filterwarnings('ignore')

# %%
def trainTest(IDrain1_Train, VSource1_Train, IDrain1_Test, VSource1_Test, IDrain2_Test, VSource2_Test):
    start_time = 0
    X = IDrain1_Train[start_time:].reshape(-1,1)

    y = VSource1_Train[start_time:].reshape(-1,1)
    y = (y == np.nanmax(y))

    X_Test=IDrain1_Test[start_time:].reshape(-1,1)
    X_Test2=IDrain2_Test[start_time:].reshape(-1,1)
    y_Test=VSource1_Test[start_time:].reshape(-1,1)
    y_Test = (y_Test == np.nanmax(y_Test))
    y_Test2=VSource2_Test[start_time:].reshape(-1,1)
    y_Test2 = (y_Test == np.nanmax(y_Test2))

#     clf = SVC(kernel = 'linear', C = 1, probability = False).fit(X, y) #change kernel here
    clf = LinearDiscriminantAnalysis().fit(X, y)

#     y_pred = clf.predict(X_Test2)
#     y_pred2 = clf.predict(X_Test)

#     print('Test 1 accuracy:', clf.score(X_Test, y_Test), '| Time Delay:', sep_Test1, '| Test Class:', classifier[0][simNum_Test1], '| Train Class:',  classifier[0][simNum_Train])
#     print('Test 2 accuracy:', clf.score(X_Test2, y_Test2), '| Time Delay:', sep_Test2, '| Test Class:', classifier[0][simNum_Test2], '| Train Class:',  classifier[0][simNum_Train])
    
    # Plot hack
    lin = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)
    boundary = lin[np.argmax(clf.predict(lin))][0]
    
    return clf.score(X_Test, y_Test), clf.score(X_Test2, y_Test2),clf.score(X, y), boundary

# %%
# Load Samples for Early/Mid/Late/Never

# path= r"C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN/data/collapsed/Path Length 4/"
path= r"C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN/data/collapsed/Variable Path Length/"

connectivityPath="C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN/connectivity_data/"

# classifier = loadmat(connectivityPath +'emln_1.5_PL4.mat')['bang']
classifier = loadmat(connectivityPath +'emln_1.5.mat')['bang']

pairinglist=loadmat(connectivityPath +'ElecPos.mat')['elecPos']-1
# pairinglist=loadmat(connectivityPath +'ElecPosPathLength.mat')['ElecPos']

pairinglist[0,:] = np.array([4,17])
pairinglist[80,:] = np.array([22, 80])
pairinglist[81,:] = np.array([99, 81])

# %%
adj = loadmat('connectivity_data/AdjMat100nw.mat')['adjmat'].todense()
theAlon = nx.from_numpy_array(adj)

Connectivity = connectivity__(graph = theAlon)

# Which pairings have the same length? & Different COMM values
adjMat=Connectivity.adj_matrix
pathLength=8;

distMat = np.zeros(adjMat.shape)
distMatElec= np.zeros(pairinglist.shape[0])
G = nx.from_numpy_array(adjMat)
# for i in range(adjMat[:,0].size):
#      for j in range(i+1, adjMat[:,0].size):
#         distMat[i,j] = nx.shortest_path_length(G, i, j)
# distMat = distMat + distMat.T

rows=len(pairinglist)
for i in range(rows):
        distMatElec[i]=nx.shortest_path_length(G,pairinglist[i,0],pairinglist[i,1])
        
pathLength=distMatElec

# %%
distMatElec
# Out:
# array([ 3.,  3.,  6., 10.,  3.,  6.,  4.,  8.,  7.,  6.,  6., 12.,  9.,
#         3.,  1.,  3.,  6.,  7.,  5.,  2.,  9.,  4.,  2.,  3.,  7.,  4.,
#         7.,  4.,  3.,  9.,  8.,  3.,  2.,  9.,  5.,  5.,  3.,  7.,  5.,
#         4.,  5.,  3.,  8., 10.,  1.,  3., 10.,  6.,  5.,  7.,  6.,  4.,
#         4.,  6.,  4.,  7.,  1.,  5.,  5.,  4.,  7.,  5.,  3.,  9.,  1.,
#         1.,  2.,  5.,  1.,  5.,  2.,  5.,  4., 10.,  3.,  6.,  2.,  6.,
#         1.,  5.,  7.,  5.,  9.,  1.,  1.,  3.,  6.,  6.,  3.,  1.,  1.,
#         7.,  2.,  7.,  9.,  6.,  6.,  4.,  2.,  4.])

# %%
early = np.where(classifier[0] == 0)[0]
mid = np.where(classifier[0] == 1)[0]
late = np.where(classifier[0] == 2)[0]
never = np.where(classifier[0] == 3)[0]

earlyRand=np.random.choice(early,1)[0]
midRand=np.random.choice(mid,1)[0]
lateRand=np.random.choice(late,1)[0]
neverRand=np.random.choice(never,1)[0]

randPair_idx = [earlyRand, midRand, lateRand, neverRand]

randPairings = [pairinglist[i] for i in randPair_idx]

# earlyPair=pairinglist[earlyRand]
# midPair=pairinglist[midRand]
# latePair=pairinglist[lateRand]
# neverPair=pairinglist[neverRand]

# randPairings = [earlyPair, midPair, latePair, neverPair]
time_seps = [50, 500, 1000]
sperm = [i for i in permutations([0,1,2,3],3)]
time_sperm = [i for i in permutations([0,1,2],3)]

# %%
master_sperm = []
for i in range(len(sperm)):
# for i in range(14):
# for i in range(1):
    train, test1, test2 = randPairings[sperm[i][0]], randPairings[sperm[i][1]], randPairings[sperm[i][2]]
    pathTrain, pathTest1, pathTest2 = pathLength[randPair_idx[sperm[i][0]]], pathLength[randPair_idx[sperm[i][1]]], pathLength[randPair_idx[sperm[i][2]]]
    file_train = loadmat(path+'source_'+str(train[0])+'_drain_'+str(train[1]))
    file_test1 = loadmat(path+'source_'+str(test1[0])+'_drain_'+str(test1[1]))
    file_test2 = loadmat(path+'source_'+str(test2[0])+'_drain_'+str(test2[1]))
    for j in range(len(time_sperm)):
        train_sep, test1_sep, test2_sep = time_seps[time_sperm[j][0]], time_seps[time_sperm[j][1]], time_seps[time_sperm[j][2]]
        train_IDrain = file_train['sep_'+str(train_sep)][0][0]['IDrain1']
        train_VSource = file_train['sep_'+str(train_sep)][0][0]['VSource1']
        test1_IDrain = file_test1['sep_'+str(test1_sep)][0][0]['IDrain1']
        test1_VSource = file_test1['sep_'+str(test1_sep)][0][0]['VSource1']
        test2_IDrain = file_test2['sep_'+str(test2_sep)][0][0]['IDrain1']
        test2_VSource = file_test2['sep_'+str(test2_sep)][0][0]['VSource1']
        score1, score2, scoreTrain, boundary = trainTest(train_IDrain, train_VSource, test1_IDrain, test1_VSource, test2_IDrain, test2_VSource)
        
        temp_dict = dict(train_class = sperm[i][0],
                         train_sep = train_sep,
                         train_accuracy= scoreTrain,
                         test1_class = sperm[i][1],
                         test1_sep = test1_sep,
                         test1_accuracy = score1,
                         test2_calss = sperm[i][2],
                         test2_sep = test2_sep,
                         test2_accuracy = score2,
                         boundary = boundary,
                         train_pathLength = pathTrain,
                         test1_pathLength = pathTest1,
                         test2_pathLength = pathTest2)                                
        master_sperm.append(temp_dict)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat)
#      30     try:
# ---> 31         return open(file_like, 'rb'), True
#      32     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN/data/collapsed/Variable Path Length/source_33_drain_12'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-131-39fc3ce31edf> in <module>
#       5     train, test1, test2 = randPairings[sperm[i][0]], randPairings[sperm[i][1]], randPairings[sperm[i][2]]
#       6     pathTrain, pathTest1, pathTest2 = pathLength[randPair_idx[sperm[i][0]]], pathLength[randPair_idx[sperm[i][1]]], pathLength[randPair_idx[sperm[i][2]]]
# ----> 7     file_train = loadmat(path+'source_'+str(train[0])+'_drain_'+str(train[1]))
#       8     file_test1 = loadmat(path+'source_'+str(test1[0])+'_drain_'+str(test1[1]))
#       9     file_test2 = loadmat(path+'source_'+str(test2[0])+'_drain_'+str(test2[1]))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\io\matlab\mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     205     """
#     206     variable_names = kwargs.pop('variable_names', None)
# --> 207     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
#     208     matfile_dict = MR.get_variables(variable_names)
#     209     if mdict is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\io\matlab\mio.py in mat_reader_factory(file_name, appendmat, **kwargs)
#      60
#      61     """
# ---> 62     byte_stream, file_opened = _open_file(file_name, appendmat)
#      63     mjv, mnv = get_matfile_version(byte_stream)
#      64     if mjv == 0:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\io\matlab\mio.py in _open_file(file_like, appendmat)
#      35             if appendmat and not file_like.endswith('.mat'):
#      36                 file_like += '.mat'
# ---> 37             return open(file_like, 'rb'), True
#      38         else:
#      39             raise IOError('Reader needs file name or open file-like object')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN/data/collapsed/Variable Path Length/source_33_drain_12.mat'

# %%
master_sperm
# Out:
# [{'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9095,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9095,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9185,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9905,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9185,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9905,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9905,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9905,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9185,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9185,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9095,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9375,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 9.02949368408631e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9095,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.812521124255817e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9305,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 8.682749639270365e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8695,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8695,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8615,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8615,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.933,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9325,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.933,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9135,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9325,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9135,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 1.0,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9695,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9695,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9615,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9615,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.933,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 1.0,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9325,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9695,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.933,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9695,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9135,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9615,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9325,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9615,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9135,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9675,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.967,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.967,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9675,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9675,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.956,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.967,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 6.804476146698098e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8695,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9535,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.967,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8695,
#   'boundary': 6.536718973342572e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8615,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.928,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9675,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8615,
#   'boundary': 6.457856661845743e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8475,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8475,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9295,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9245,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9295,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9275,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9275,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9295,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9275,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9245,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.9295,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9275,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.9,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.9,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9755,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9705,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9705,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9755,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8475,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9705,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 6.047653946453271e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8475,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9705,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 5.980995913921024e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 1.0,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.945,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 1.0,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 5.861572609056321e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.831,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.831,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.831,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.831,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.831,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9215,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.831,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.831,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.831,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.831,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.831,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.831,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9375,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.831,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.931,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.931,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.931,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.931,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.931,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.931,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8215,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.931,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.931,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.414858968199378e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.931,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 1.0,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.931,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.283983479340971e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.931,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.986,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.931,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8375,
#   'boundary': 4.140465089126559e-05,
#   'train_pathLength': 4.0,
#   'test1_pathLength': 4.0,
#   'test2_pathLength': 4.0}]

# %%
# Explore
def plotTimeSeries(VSource1_Test,VSource1_Train,IDrain1_Train,IDrain1_Test,IDrain2_Test,VSource2_Test, boundary = None):
    fig, axes = plt.subplots(1, 2, figsize=(16, 4))

    axes[0].plot(VSource1_Train.ravel(), label = 'VSource Train'); axes[0].plot(VSource1_Test.ravel(), label = 'VSource Test'); axes[0].plot(VSource2_Test.ravel(), label = 'VSource Test2')
    axes[0].set_title("Input to device - Target for learning (y)"); axes[0].set_xlabel('Time'); axes[0].set_ylabel('V')
    axes[0].legend()
    axes[1].plot(IDrain1_Train.ravel(), label = 'IDrain Train'); axes[1].plot(IDrain1_Test.ravel(), label = 'IDrain Test'); axes[1].plot(IDrain2_Test.ravel(), label = 'IDrain Test2')
    axes[1].set_title("Output of device - Features for learning (X)"); axes[1].set_xlabel('Time'); axes[1].set_ylabel('A')
    axes[1].legend()
    
    if boundary is not None:
        axes[1].axhline(boundary, linestyle = '--', color = 'k')

    # fig.savefig(save_path + filename_train_save + m + '_Training_Parameters_'+datetime.datetime.now().strftime("%Y-%m-%d") +'.jpg')
    # fig.savefig(save_path + filename_train_save + m +'_Training_Parameters_'+datetime.datetime.now().strftime("%Y-%m-%d") +'.eps')
    return axes

# %%
plotTimeSeries(test1_VSource,train_VSource,train_IDrain,test1_IDrain,test2_IDrain,test2_VSource, boundary)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE61089B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000019AE6109BA8>],
#       dtype=object)

# %%
# import csv

# keys = master_sperm[0].keys()
# with open('exp4_classification_v1.5_PathLength4_sp1000.csv', 'w') as output_file:
#     dict_writer = csv.DictWriter(output_file, keys)
#     dict_writer.writeheader()
#     dict_writer.writerows(master_sperm)

# savemat(path+"exp4_classification_v1.5_PathLength4_sp1000.mat",dict(Data=master_sperm))
savemat(path+"exp4_classification_v1.5_variablePathLength_sp1000.mat",dict(Data=master_sperm))

# %%
plt.plot(test1_VSource[0])

# %%
train_IDrain.max()
# Out:
# 6.767601078871039e-05

# %%
test1_VSource.shape
# Out:
# (1, 2000)

# %%
lin = np.linspace(train_IDrain.min(), train_IDrain.max(), 50)

# %%
# Out:
# array([7.18957203e-08, 1.45157154e-06, 2.83124736e-06, 4.21092317e-06,
#        5.59059899e-06, 6.97027481e-06, 8.34995063e-06, 9.72962644e-06,
#        1.11093023e-05, 1.24889781e-05, 1.38686539e-05, 1.52483297e-05,
#        1.66280055e-05, 1.80076814e-05, 1.93873572e-05, 2.07670330e-05,
#        2.21467088e-05, 2.35263846e-05, 2.49060604e-05, 2.62857363e-05,
#        2.76654121e-05, 2.90450879e-05, 3.04247637e-05, 3.18044395e-05,
#        3.31841153e-05, 3.45637912e-05, 3.59434670e-05, 3.73231428e-05,
#        3.87028186e-05, 4.00824944e-05, 4.14621703e-05, 4.28418461e-05,
#        4.42215219e-05, 4.56011977e-05, 4.69808735e-05, 4.83605493e-05,
#        4.97402252e-05, 5.11199010e-05, 5.24995768e-05, 5.38792526e-05,
#        5.52589284e-05, 5.66386042e-05, 5.80182801e-05, 5.93979559e-05,
#        6.07776317e-05, 6.21573075e-05, 6.35369833e-05, 6.49166592e-05,
#        6.62963350e-05, 6.76760108e-05])
