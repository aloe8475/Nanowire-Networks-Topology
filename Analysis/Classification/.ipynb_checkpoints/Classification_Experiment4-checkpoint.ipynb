# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

from itertools import permutations 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, Normalizer

# %%
def trainTest(IDrain1_Train, VSource1_Train, IDrain1_Test, VSource1_Test, IDrain2_Test, VSource2_Test):
    start_time = 0
    X = IDrain1_Train[start_time:].reshape(-1,1)

    y = VSource1_Train[start_time:].reshape(-1,1)
    y = (y == np.nanmax(y))

    X_Test=IDrain1_Test[start_time:].reshape(-1,1)
    X_Test2=IDrain2_Test[start_time:].reshape(-1,1)
    y_Test=VSource1_Test[start_time:].reshape(-1,1)
    y_Test = (y_Test == np.nanmax(y_Test))
    y_Test2=VSource2_Test[start_time:].reshape(-1,1)
    y_Test2 = (y_Test == np.nanmax(y_Test2))

    clf = LinearDiscriminantAnalysis().fit(X, y)

#     y_pred = clf.predict(X_Test2)
#     y_pred2 = clf.predict(X_Test)

#     print('Test 1 accuracy:', clf.score(X_Test, y_Test), '| Time Delay:', sep_Test1, '| Test Class:', classifier[0][simNum_Test1], '| Train Class:',  classifier[0][simNum_Train])
#     print('Test 2 accuracy:', clf.score(X_Test2, y_Test2), '| Time Delay:', sep_Test2, '| Test Class:', classifier[0][simNum_Test2], '| Train Class:',  classifier[0][simNum_Train])
    return clf.score(X_Test, y_Test), clf.score(X_Test2, y_Test2),clf.score(X, y)

# %%
# Load Samples for Early/Mid/Late/Never

path= r"C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN/data/Collapsed/"

classifier = loadmat(path+'emln.mat')['bang']
pairinglist=loadmat(path+'ElecPos.mat')['elecPos']-1
pairinglist[0,:] = np.array([4,17])
pairinglist[80,:] = np.array([22, 80])
pairinglist[81,:] = np.array([99, 81])

# %%
early = np.where(classifier[0] == 0)[0]
mid = np.where(classifier[0] == 1)[0]
late = np.where(classifier[0] == 2)[0]
never = np.where(classifier[0] == 3)[0]

earlyRand=np.random.choice(early,1)[0]
midRand=np.random.choice(mid,1)[0]
lateRand=np.random.choice(late,1)[0]
neverRand=np.random.choice(never,1)[0]

earlyPair=pairinglist[earlyRand]
midPair=pairinglist[midRand]
latePair=pairinglist[lateRand]
neverPair=pairinglist[neverRand]

randPairings = [earlyPair, midPair, latePair, neverPair]
time_seps = [50, 500, 1000]
sperm = [i for i in permutations([0,1,2,3],3)]
time_sperm = [i for i in permutations([0,1,2],3)]

# %%
master_sperm = []
for i in range(len(sperm)):
    train, test1, test2 = randPairings[sperm[i][0]], randPairings[sperm[i][1]], randPairings[sperm[i][2]]
    file_train = loadmat(path+'source_'+str(train[0])+'_drain_'+str(train[1]))
    file_test1 = loadmat(path+'source_'+str(test1[0])+'_drain_'+str(test1[1]))
    file_test2 = loadmat(path+'source_'+str(test2[0])+'_drain_'+str(test2[1]))
    for j in range(len(time_sperm)):
        train_sep, test1_sep, test2_sep = time_seps[time_sperm[j][0]], time_seps[time_sperm[j][1]], time_seps[time_sperm[j][2]]
        train_IDrain = file_train['sep_'+str(train_sep)][0][0]['IDrain1']
        train_VSource = file_train['sep_'+str(train_sep)][0][0]['VSource1']
        test1_IDrain = file_test1['sep_'+str(test1_sep)][0][0]['IDrain1']
        test1_VSource = file_test1['sep_'+str(test1_sep)][0][0]['VSource1']
        test2_IDrain = file_test2['sep_'+str(test2_sep)][0][0]['IDrain1']
        test2_VSource = file_test2['sep_'+str(test2_sep)][0][0]['VSource1']
        score1, score2, scoreTrain = trainTest(train_IDrain, train_VSource, test1_IDrain, test1_VSource, test2_IDrain, test2_VSource)
        temp_dict = dict(train_class = sperm[i][0],
                         train_sep = train_sep,
                         train_accuracy= scoreTrain,
                         test1_class = sperm[i][1],
                         test1_sep = test1_sep,
                         test1_accuracy = score1,
                         test2_calss = sperm[i][2],
                         test2_sep = test2_sep,
                         test2_accuracy = score2)
                         
        master_sperm.append(temp_dict)
# Out:
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\aloe8475\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
master_sperm
# Out:
# [{'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8515},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.981,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8335},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8455},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.981,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.828},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.828},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.828},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.981,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.981,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9665,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.819},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9485,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.972,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.819},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9545,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.972,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.972,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9665,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9485,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.972,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9545,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.972,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.972,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.819},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.819},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8165},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8515},
#  {'train_class': 0,
#   'train_sep': 50,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8335},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8455},
#  {'train_class': 0,
#   'train_sep': 500,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.828},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.828},
#  {'train_class': 0,
#   'train_sep': 1000,
#   'train_accuracy': 0.9895,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.828},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8545},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8355},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8545},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8355},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8335},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8335},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9645,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9455,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9645,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9455,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9665,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9665,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9645,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9455,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9645,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9455,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9665,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9665,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 1.0},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8545},
#  {'train_class': 1,
#   'train_sep': 50,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8355},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8545},
#  {'train_class': 1,
#   'train_sep': 500,
#   'train_accuracy': 0.9835,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8355},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8335},
#  {'train_class': 1,
#   'train_sep': 1000,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.8,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8335},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8185},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8165},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8135},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8135},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.838},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8255},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.838},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8255},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8195},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8195},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9835,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.838},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8255},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 3,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.838},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8255},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 3,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8195},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 3,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8195},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9745,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.962,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9745,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.962,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9805,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9805,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9745,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8185},
#  {'train_class': 2,
#   'train_sep': 50,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.962,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8165},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9745,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8135},
#  {'train_class': 2,
#   'train_sep': 500,
#   'train_accuracy': 0.981,
#   'test1_class': 3,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.962,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 3,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9805,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8135},
#  {'train_class': 2,
#   'train_sep': 1000,
#   'train_accuracy': 0.9715,
#   'test1_class': 3,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9805,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8235},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8235},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 0,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9895,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8235},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8235},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 1,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9865,
#   'test2_calss': 2,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8185},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9765,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 0,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9765,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 0,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 0,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8105},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 50,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9765,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 1,
#   'test2_sep': 1000,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 500,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 1000,
#   'test1_accuracy': 0.9765,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 50,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 1,
#   'test2_sep': 500,
#   'test2_accuracy': 0.8135},
#  {'train_class': 3,
#   'train_sep': 1000,
#   'train_accuracy': 0.9865,
#   'test1_class': 2,
#   'test1_sep': 500,
#   'test1_accuracy': 0.9815,
#   'test2_calss': 1,
#   'test2_sep': 50,
#   'test2_accuracy': 0.8135}]

# %%
# Explore
def plotTimeSeries(VSource1_Test,VSource1_Train,IDrain1_Train,IDrain1_Test,IDrain2_Test,VSource2_Test):
    fig, axes = plt.subplots(1, 2, figsize=(16, 4))

    axes[0].plot(VSource1_Train.ravel(), label = 'VSource Train'); axes[0].plot(VSource1_Test.ravel(), label = 'VSource Test'); axes[0].plot(VSource2_Test.ravel(), label = 'VSource Test2')
    axes[0].set_title("Input to device - Target for learning (y)"); axes[0].set_xlabel('Time'); axes[0].set_ylabel('V')
    axes[0].legend()
    axes[1].plot(IDrain1_Train.ravel(), label = 'IDrain Train'); axes[1].plot(IDrain1_Test.ravel(), label = 'IDrain Test'); axes[1].plot(IDrain2_Test.ravel(), label = 'IDrain Test2')
    axes[1].set_title("Output of device - Features for learning (X)"); axes[1].set_xlabel('Time'); axes[1].set_ylabel('A')
    axes[1].legend()

    # fig.savefig(save_path + filename_train_save + m + '_Training_Parameters_'+datetime.datetime.now().strftime("%Y-%m-%d") +'.jpg')
    # fig.savefig(save_path + filename_train_save + m +'_Training_Parameters_'+datetime.datetime.now().strftime("%Y-%m-%d") +'.eps')
    return axes

# %%
plotTimeSeries(test1_VSource,train_VSource,train_IDrain,test1_IDrain,test2_IDrain,test2_VSource)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002563B121B00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002563E502550>],
#       dtype=object)
