# %%
cd "C:/Users/aloe8475/Dropbox (Sydney Uni)/Data/ASN_simulation/Python/ASN"
# Out:
# C:\Users\aloe8475\Dropbox (Sydney Uni)\Data\ASN_simulation\Python\ASN

# %%
from scipy.io import loadmat, savemat
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
import datetime
import networkx as nx
from utils import *
from draw.draw_graph import draw_graph
from tqdm import tqdm_notebook
import os

import warnings
warnings.filterwarnings('ignore')

# %%
AgNW = loadmat(r"C:\Users\aloe8475\Documents\PhD\GitHub\CODE\Data\Raw\Networks\Zdenka Networks\AdriantoZdenka100nw_simulation1.mat")
AgNW300 = loadmat(r"C:\Users\aloe8475\Documents\PhD\GitHub\CODE\Data\Raw\Networks\Zdenka Networks\AdriantoZdenka300nw_simulation1.mat")

adjMat=np.array(AgNW300['SelNet'][0][0][6][0][0]['SelLayout'][0][0][0][0][0].todense())
cElegans=loadmat(r"C:\Users\aloe8475\Documents\PhD\GitHub\CODE\Data\Organic Networks Connectomes\celegans277neurons.mat")

# %%
elegansMat=cElegans['celegans277matrix']
elegansGraph = nx.from_numpy_array(elegansMat)

# %%
path="C:/Users/aloe8475/Documents/PhD/GitHub/CODE/Data/Raw/Networks/Zdenka Networks/100nw Alternate NWs/"
path2="C:/Users/aloe8475/Documents/PhD/GitHub/CODE/Data/Raw/Networks/Zdenka Networks/500nw Alternate NWs/"
path3="C:/Users/aloe8475/Documents/PhD/GitHub/CODE/Data/Raw/Networks/Zdenka Networks/300nw Alternate NWs/"

# %%
AgNWs=[]
AgNWs300=[]
AgNWs500=[]

for file in os.listdir( path ) :
    AgNWs.append(np.array(loadmat( path+file )['SelNet'][0][0][6][0][0]['SelLayout'][0][0][0][0][0].todense()))
for file in os.listdir(path2):
    AgNWs500.append(np.array(loadmat( path2+file )['SelNet'][0][0][6][0][0]['SelLayout'][0][0][0][0][0].todense()))
for file in os.listdir(path3):
    AgNWs300.append(np.array(loadmat( path3+file )['SelNet'][0][0][6][0][0]['SelLayout'][0][0][0][0][0].todense()))

# %%
nwEdges=[np.sum(AgNWs[i]) for i in range(len(AgNWs))]
nwEdges.remove(678.0)
nwEdges = np.array(nwEdges)

nwEdges2=[np.sum(AgNWs300[i]) for i in range(len(AgNWs300))]
# nwEdges2.remove(678.0)
nwEdges2 = np.array(nwEdges2)

nwEdges500=[np.sum(AgNWs500[i]) for i in range(len(AgNWs500))]
# nwEdges2.remove(678.0)
nwEdges500 = np.array(nwEdges500)

nwEdgesElegans=[np.sum(elegansMat)]

# %%
#Average degree?
a=np.array(list(elegansGraph.degree))
np.mean(a[:,1])
# Out:
# 13.848375451263538

# %%
avgDegree=nwEdges2/300

# %%
ws=[]
sim=[None]*27 # change to length of ws
sim2=[None]*len(AgNWs)
sim3=[None]*len(AgNWs300)
sim4=[None]*len(AgNWs500)

# %%
commuMat=[None]*27 #change to length of ws
currMat=[None]*27
commuMat2=[None]*len(AgNWs)
currMat2=[None]*len(AgNWs)
currMat3=[None]*len(AgNWs300)
commuMat3=[None]*len(AgNWs300)
currMat4=[None]*len(AgNWs500)
commuMat4=[None]*len(AgNWs500)

# %%
#Subgraph AdjMat
def getOnGraph(network, this_TimeStamp = 0):
    edgeList = network.connectivity.edge_list
    adjMat = np.zeros((network.numOfWires, network.numOfWires))
    adjMat[edgeList[:,0], edgeList[:,1]] = network.junctionSwitch[this_TimeStamp,:]
    adjMat[edgeList[:,1], edgeList[:,0]] = network.junctionSwitch[this_TimeStamp,:]
    onGraph = nx.from_numpy_array(adjMat)
    
    return onGraph

# %%
for beta in [0.15,0.5,1]:
    for i in range(len(avgDegree)):
        ws.append(nx.watts_strogatz_graph(300,int(np.round(avgDegree[i])),beta)) #change 300 to 100 if you want 100nw

# %%
for i in range(len(ws)):
# for i in range(1,2):
    sim[i] = defaultSimulation(connectivity__(graph=ws[i]), T = 2, biasType = 'DC', onAmp = 1, findFirst = False)
for i in range(len(AgNWs)):
    sim2[i] = defaultSimulation(connectivity__(adjMat=AgNWs[i]), T = 2, biasType = 'DC', onAmp = 1, findFirst = False)
for i in range(len(AgNWs300)):    
    sim3[i] = defaultSimulation(connectivity__(adjMat=AgNWs300[i]), T = 2, biasType = 'DC', onAmp = 1, findFirst = False)
for i in range(len(AgNWs500)):    
    sim4[i] = defaultSimulation(connectivity__(adjMat=AgNWs500[i]), T = 2, biasType = 'DC', onAmp = 1, findFirst = False)
# Out:
# ...
# Running Simulation : 100%|████████████████████████████████████████████████████████| 2000/2000 [00:13<00:00, 150.59it/s]

# %%
sim5= defaultSimulation(connectivity__(graph=elegansGraph), T = 2, biasType = 'DC', onAmp = 1, findFirst = False)
# Out:
# Running Simulation : 100%|███████████████████████████████████████████████████████| 2000/2000 [00:01<00:00, 1027.87it/s]

# %%
def commCurr(sim):

    currMat = np.zeros((sim.numOfWires,sim.numOfWires))
    edgeList = sim.connectivity.edge_list
    currMat[edgeList[:,0], edgeList[:,1]] = sim.junctionVoltage[-1,:]/sim.junctionResistance[-1,:]
    currMat = currMat + currMat.T
    currGraph = nx.from_numpy_array(currMat)
    subGraph = getOnGraph(sim, sim.TimeVector.size-1)

    components = [i for i in nx.connected_components(subGraph)]

    max_ind = np.argmax([len(i) for i in nx.connected_components(subGraph)])
    currGraph = nx.subgraph(currGraph, components[max_ind])
    currGraph = nx.from_numpy_array(nx.adjacency_matrix(currGraph).todense())
    currMat = np.array(nx.adjacency_matrix(currGraph).todense())

    commu = nx.communicability(currGraph)
    subSize = len(currGraph)
    commu_Mat = np.array([commu[k][j] for k in range(subSize) for j in range(subSize)]).reshape(subSize,subSize)
    
    return commu_Mat, currMat

# %%
for i in tqdm_notebook(range(len(sim)), desc = 'I like it !'):
    commuMat[i],currMat[i]=commCurr(sim[i])
    
for i in tqdm_notebook(range(len(sim2)), desc = 'I like it 2 !'):
    commuMat2[i],currMat2[i]=commCurr(sim2[i])
    
for i in tqdm_notebook(range(len(sim3)), desc = 'I like it 3 !'):
    commuMat3[i],currMat3[i]=commCurr(sim3[i])    

for i in tqdm_notebook(range(len(sim4)), desc = 'I like it 4 !'):
    commuMat4[i],currMat4[i]=commCurr(sim4[i])   
    
commuMat5,currMat5=commCurr(sim5) 
print('I LOVE ITTTTT')
# Out:
# ...
# I LOVE ITTTTT

# %%
# %matplotlib notebook

# %%
plt.figure()
for i in range(len(commuMat4)):
        plt.scatter(commuMat4[i][currMat4[i]!=0], abs(currMat4[i][currMat4[i]!=0]), color='#FFBE33',alpha=0.4)
for i in range(len(commuMat3)):
        plt.scatter(commuMat3[i][currMat3[i]!=0], abs(currMat3[i][currMat3[i]!=0]), c='#FF5233',alpha=0.4)
for i in range(len(commuMat2)):
    plt.scatter(commuMat2[i][currMat2[i]!=0], abs(currMat2[i][currMat2[i]!=0]), c='#FF1212',alpha=0.4)

for i in range(len(commuMat)):
    if i <10:
        plt.scatter(commuMat[i][currMat[i]!=0], abs(currMat[i][currMat[i]!=0]), color = 'c',alpha=0.9)
    elif i <20:
        plt.scatter(commuMat[i][currMat[i]!=0], abs(currMat[i][currMat[i]!=0]), color = 'm',alpha=0.9)
    else:
        plt.scatter(commuMat[i][currMat[i]!=0], abs(currMat[i][currMat[i]!=0]), color = 'g',alpha=0.9)

plt.scatter(commuMat5[currMat5!=0], abs(currMat5[currMat5!=0]), c='#FCF400',alpha=0.4)

plt.xscale("log")
plt.ylim(0,0.00007)
plt.xlim(1,1e14+500)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (1, 100000000000500.0)

# %%
plt.figure(figsize=(14,7))
for i in range(27):
    randSize = commuMat[i][currMat[i]!=0].size
    
    if i < 9:
        xrand = np.random.normal(1, 0.05, randSize)
        plt.scatter(xrand, commuMat[i][currMat[i]!=0], color = 'c',s=1)
    elif i < 18:
        xrand = np.random.normal(2, 0.05, randSize)
        plt.scatter(xrand, commuMat[i][currMat[i]!=0], color = 'm',s=1)
    else:
        xrand = np.random.normal(3, 0.05, randSize)
        plt.scatter(xrand, commuMat[i][currMat[i]!=0], color = 'g',s=1)
        
for i in range(len(AgNWs)):
    randSize2 = commuMat2[i][currMat2[i]!=0].size    
    xrand2 = np.random.normal(4, 0.05, randSize2)
    plt.scatter(xrand2, commuMat2[i][currMat2[i]!=0], color = '#FF1212',s=1)
    

randSize5 = commuMat5[currMat5!=0].size    
xrand5 = np.random.normal(5, 0.05, randSize5)
plt.scatter(xrand5, commuMat5[currMat5!=0], color = '#FCF400',s=1)    
    
for i in range(len(AgNWs300)):
    randSize3 = commuMat3[i][currMat3[i]!=0].size    
    xrand3 = np.random.normal(6, 0.05, randSize3)
    plt.scatter(xrand3, commuMat3[i][currMat3[i]!=0], color = '#FF5233',s=1)
    
    
for j in range(len(AgNWs500)):
    randSize4 = commuMat4[j][currMat4[j]!=0].size    
    xrand4 = np.random.normal(7, 0.05, randSize4)
    plt.scatter(xrand4, commuMat4[j][currMat4[j]!=0], color = '#FFBE33',s=1)    


plt.yscale("log")
plt.ylim(1)
plt.xticks([1,2,3,4,5,6,7],[r"300Node WS $\beta$ = 0.15",r"300Node WS $\beta$ = 0.5", r"300Node WS $\beta$ = 1", "100 AgNW Networks", r"$\it{C. Elegans}$", "300AgNW Networks","500 AgNW Networks"])
plt.ylabel("log(Communicability)")
# Out:
# <img src="data:image/png;base64,..." width="1120">
# Text(0, 0.5, 'log(Communicability)')

# %%
xrand4.shape
# Out:
# (5208,)

# %%
savemat(r"C:\Users\aloe8475\Documents\PhD\GitHub\CODE\Data\Explore Analysis\Ordered+Random Data\WScomm_curr_plots.mat",dict(randNoise=[xrand, xrand2, xrand3, xrand4, xrand5], COMM=[commuMat,commuMat2, commuMat3, commuMat4,commuMat5], Curr=[currMat, currMat2, currMat3, currMat4, currMat4]))

# %%
# %matplotlib inline

# %%
draw_graph(sim[0],time=4,figsize=(30,30))
# Out:
# Input time exceeds simulation period.
