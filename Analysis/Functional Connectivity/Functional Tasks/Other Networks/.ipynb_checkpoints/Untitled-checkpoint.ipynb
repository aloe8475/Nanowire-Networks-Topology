# %%
import sys
sys.path.append('/import/silo2/aloe8475/Documents/edamame')

# %%
saveFig='/import/silo2/aloe8475/Documents/CODE/Data/Figures/Functional Connectivity/'

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import datetime
import networkx as nx
from edamame import *
from tqdm.notebook import tqdm_notebook as tqdm
import os
import edamame.core.wires as wires
from random import choice
from IPython.core.debugger import set_trace
# import nct
import bct

import pickle 
import _pickle as cPickle
import gzip
def compressed_pickle(obj, filename,protocol=-1):
    with gzip.open(filename, 'wb') as f:
        cPickle.dump(obj, f, protocol)
def decompress_pickle(file):
    with gzip.open(file, 'rb') as f:
        loaded_object = cPickle.load(f)
        return loaded_object

# %%
this_seed=8639#np.random.randint(10000)
Network=edamame.core.generate_network(25,dispersion=120,mean_length=200)
connectivity=connectivity__(wires_dict=Network)

xa=connectivity.xa
xb=connectivity.xb
ya=connectivity.ya
yb=connectivity.yb
# Out:
# 2021-06-22 13:51:16,043:INFO:Detecting junctions
# 2021-06-22 13:51:16,055:INFO:Finished detecting junctions
# 2021-06-22 13:51:16,058:WARNING:This graph has    3 connected components
# 2021-06-22 13:51:16,060:INFO:Detecting junctions
# 2021-06-22 13:51:16,072:INFO:Finished detecting junctions
# 2021-06-22 13:51:16,075:WARNING:This graph has    2 connected components
# 2021-06-22 13:51:16,078:INFO:Detecting junctions
# 2021-06-22 13:51:16,089:INFO:Finished detecting junctions
# 2021-06-22 13:51:16,091:INFO:The returned network has 87 junctions.

# %%
pos=nx.kamada_kawai_layout(connectivity.G)
nx.draw(connectivity.G,pos=pos)
plt.savefig(saveFig+'NWN_25Nodes_87Junctions.pdf',format='pdf',dpi=300)
