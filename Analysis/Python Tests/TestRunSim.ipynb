# %%
cd "C:\Users\61424\Dropbox (Sydney Uni)\Data\ASN_simulation\Python\edamame"
# Out:
# C:\Users\61424\Dropbox (Sydney Uni)\Data\ASN_simulation\Python\edamame

# %%
from scipy.io import loadmat
from edamame import *
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft

# %%
data = loadmat(r"C:\Users\61424\Dropbox (Sydney Uni)\Data\ASN_simulation\Python\edamame\edamame\connectivity_data\100nw_261junctions.mat")

# %%
sim=runSim(connectivity__('100nw_261junctions.mat'),T=5,findFirst=True,biasType='MKG')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Running Simulation ', max=5000.0, style=ProgressStyle(des…
# 2020-06-16 13:20:12,813:INFO:First current path [16, 51, 69, 11, 47, 2, 39, 80, 83, 85, 58, 87] formed at time = 1.479 s.

# %%
y=sim.stimulus[0].signal
plt.plot(y)
# Out:
# C:\Users\61424\anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(sim.electrodeCurrent[:,1])
